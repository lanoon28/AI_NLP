# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc

# %%
df = pd.read_excel('관서별 5대범죄 발생 및 검거.xlsx')

# %%
df.head() # tail, describe, info => 데이터 보기
# Out:
#     관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 0     계   92679   65378     141     125     138     130    5763    4749
# 1   중부서    2057    1406       1       1       3       4     113      76
# 2   종로서    1694    1179       9       6       4       4     115      93
# 3  남대문서    1354     917       1       1       2       2      73      52
# 4  서대문서    2533    1706       3       3       2       1     159     149
#
#    절도(발생)  절도(검거)  폭력(발생)  폭력(검거)
# 0   38293   19355   48344   41019
# 1     943     495     997     830
# 2     602     284     964     792
# 3     699     368     579     494
# 4    1077     524    1292    1029

# %%
police_to_gu = {'서대문서': '서대문구', '수서서': '강남구', '강서서': '강서구', '서초서': '서초구',
                '서부서': '은평구', '중부서': '중구', '종로서': '종로구', '남대문서': '중구',
                '혜화서': '종로구', '용산서': '용산구', '성북서': '성북구', '동대문서': '동대문구',
                '마포서': '마포구', '영등포서': '영등포구', '성동서': '성동구', '동작서': '동작구',
                '광진서': '광진구', '강북서': '강북구', '금천서': '금천구', '중랑서': '중랑구',
                '강남서': '강남구', '관악서': '관악구', '강동서': '강동구', '종암서': '성북구', 
                '구로서': '구로구', '양천서': '양천구', '송파서': '송파구', '노원서': '노원구', 
                '방배서': '서초구', '은평서': '은평구', '도봉서': '도봉구'}

# %%
df['구별'] = df['관서명'].apply(lambda x : police_to_gu.get(x)) # 딕셔너리 값 추출 => get

# %%
#df.set_index('구별', inplace = True)
gu_df = pd.pivot_table(df, index='구별', aggfunc = np.sum) # 구별 합계, 집계함수

# %%
gu_df
# Out:
#       강간(검거)  강간(발생)  강도(검거)  강도(발생)      관서명  살인(검거)  살인(발생)  소계(검거)  소계(발생)  \
# 구별
# 강남구      627     708      11      14   강남서수서서       5       6    5245    7356
# 강동구      167     188      14      15      강동서       3       3    2662    3788
# 강북구      132     159       4       5      강북서       8       9    2259    2770
# 강서구      222     265       5       6      강서서       9      10    3393    4415
# 관악구      351     403       3       3      관악서      12      12    3858    5261
# 광진구      224     255       4       4      광진서       2       2    2511    3601
# 구로구      142     197       5       5      구로서       6       6    2984    4175
# 금천구       93     117       6       7      금천서       4       4    1966    2598
# 노원구      148     169       3       3      노원서       3       4    2581    3743
# 도봉구       87      82       2       2      도봉서       0       0    1490    2179
# 동대문구     142     161       5       6     동대문서       8      10    2465    3401
# 동작구      121     226       2       1      동작서       1       1    2086    3200
# 마포구      287     348       3       4      마포서       8       9    2534    3688
# 서대문구     149     159       1       2     서대문서       3       3    1706    2533
# 서초구      303     396       4       6   서초서방배서       5       5    3052    4601
# 성동구       98     115       3       3      성동서       5       5    1774    2362
# 성북구      121     142       2       3   성북서종암서       4       4    1947    2567
# 송파구      235     287      17      13      송파서       6       6    3544    5410
# 양천구       90     109       3       3      양천서       5       5    2086    3216
# 영등포구     252     315       5       6     영등포서       4       7    3371    5217
# 용산구      186     230       6       6      용산서       3       5    2056    2969
# 은평구      145     171       3       4   서부서은평서       4       4    2531    3390
# 종로구      146     192       7       7   종로서혜화서       6       9    2173    3102
# 중구       128     186       6       5  중부서남대문서       2       2    2323    3411
# 중랑구      153     183       6       5      중랑서       9      10    2781    3726
#
#       절도(검거)  절도(발생)  폭력(검거)  폭력(발생)
# 구별
# 강남구     1491    2951    3111    3677
# 강동구      781    1640    1697    1942
# 강북구      490     780    1625    1817
# 강서구     1070    1689    2087    2445
# 관악구     1137    2229    2355    2614
# 광진구      874    1664    1407    1676
# 구로구     1008    1763    1823    2204
# 금천구      553     999    1310    1471
# 노원구      646    1404    1781    2163
# 도봉구      379     861    1022    1234
# 동대문구     713    1440    1597    1784
# 동작구      592    1341    1370    1631
# 마포구      679    1483    1557    1844
# 서대문구     524    1077    1029    1292
# 서초구      960    2021    1780    2173
# 성동구      565    1016    1103    1223
# 성북구      580     988    1240    1430
# 송파구     1006    2429    2280    2675
# 양천구      718    1517    1270    1582
# 영등포구     953    2188    2157    2701
# 용산구      534    1111    1327    1617
# 은평구      756    1371    1623    1840
# 종로구      594    1183    1420    1711
# 중구       863    1642    1324    1576
# 중랑구      889    1506    1724    2022

# %%
gu_df['강간검거율'] = gu_df['강간(검거)']/gu_df['강간(발생)']*100
gu_df['강도검거율'] = gu_df['강도(검거)']/gu_df['강도(발생)']*100
gu_df['살인검거율'] = gu_df['살인(검거)']/gu_df['살인(발생)']*100
gu_df['절도검거율'] = gu_df['절도(검거)']/gu_df['절도(발생)']*100
gu_df['폭력검거율'] = gu_df['폭력(검거)']/gu_df['폭력(발생)']*100
gu_df['검거율'] = gu_df['소계(검거)']/gu_df['소계(발생)']*100

# %%
gu_df
# Out:
#       강간(검거)  강간(발생)  강도(검거)  강도(발생)      관서명  살인(검거)  살인(발생)  소계(검거)  소계(발생)  \
# 구별
# 강남구      627     708      11      14   강남서수서서       5       6    5245    7356
# 강동구      167     188      14      15      강동서       3       3    2662    3788
# 강북구      132     159       4       5      강북서       8       9    2259    2770
# 강서구      222     265       5       6      강서서       9      10    3393    4415
# 관악구      351     403       3       3      관악서      12      12    3858    5261
# 광진구      224     255       4       4      광진서       2       2    2511    3601
# 구로구      142     197       5       5      구로서       6       6    2984    4175
# 금천구       93     117       6       7      금천서       4       4    1966    2598
# 노원구      148     169       3       3      노원서       3       4    2581    3743
# 도봉구       87      82       2       2      도봉서       0       0    1490    2179
# 동대문구     142     161       5       6     동대문서       8      10    2465    3401
# 동작구      121     226       2       1      동작서       1       1    2086    3200
# 마포구      287     348       3       4      마포서       8       9    2534    3688
# 서대문구     149     159       1       2     서대문서       3       3    1706    2533
# 서초구      303     396       4       6   서초서방배서       5       5    3052    4601
# 성동구       98     115       3       3      성동서       5       5    1774    2362
# 성북구      121     142       2       3   성북서종암서       4       4    1947    2567
# 송파구      235     287      17      13      송파서       6       6    3544    5410
# 양천구       90     109       3       3      양천서       5       5    2086    3216
# 영등포구     252     315       5       6     영등포서       4       7    3371    5217
# 용산구      186     230       6       6      용산서       3       5    2056    2969
# 은평구      145     171       3       4   서부서은평서       4       4    2531    3390
# 종로구      146     192       7       7   종로서혜화서       6       9    2173    3102
# 중구       128     186       6       5  중부서남대문서       2       2    2323    3411
# 중랑구      153     183       6       5      중랑서       9      10    2781    3726
#
#       절도(검거)  절도(발생)  폭력(검거)  폭력(발생)       강간검거율       강도검거율       살인검거율  \
# 구별
# 강남구     1491    2951    3111    3677   88.559322   78.571429   83.333333
# 강동구      781    1640    1697    1942   88.829787   93.333333  100.000000
# 강북구      490     780    1625    1817   83.018868   80.000000   88.888889
# 강서구     1070    1689    2087    2445   83.773585   83.333333   90.000000
# 관악구     1137    2229    2355    2614   87.096774  100.000000  100.000000
# 광진구      874    1664    1407    1676   87.843137  100.000000  100.000000
# 구로구     1008    1763    1823    2204   72.081218  100.000000  100.000000
# 금천구      553     999    1310    1471   79.487179   85.714286  100.000000
# 노원구      646    1404    1781    2163   87.573964  100.000000   75.000000
# 도봉구      379     861    1022    1234  106.097561  100.000000         NaN
# 동대문구     713    1440    1597    1784   88.198758   83.333333   80.000000
# 동작구      592    1341    1370    1631   53.539823  200.000000  100.000000
# 마포구      679    1483    1557    1844   82.471264   75.000000   88.888889
# 서대문구     524    1077    1029    1292   93.710692   50.000000  100.000000
# 서초구      960    2021    1780    2173   76.515152   66.666667  100.000000
# 성동구      565    1016    1103    1223   85.217391  100.000000  100.000000
# 성북구      580     988    1240    1430   85.211268   66.666667  100.000000
# 송파구     1006    2429    2280    2675   81.881533  130.769231  100.000000
# 양천구      718    1517    1270    1582   82.568807  100.000000  100.000000
# 영등포구     953    2188    2157    2701   80.000000   83.333333   57.142857
# 용산구      534    1111    1327    1617   80.869565  100.000000   60.000000
# 은평구      756    1371    1623    1840   84.795322   75.000000  100.000000
# 종로구      594    1183    1420    1711   76.041667  100.000000   66.666667
# 중구       863    1642    1324    1576   68.817204  120.000000  100.000000
# 중랑구      889    1506    1724    2022   83.606557  120.000000   90.000000
#
#           절도검거율      폭력검거율        검거율
# 구별
# 강남구   50.525246  84.607017  71.302338
# 강동구   47.621951  87.384140  70.274551
# 강북구   62.820513  89.433132  81.552347
# 강서구   63.351095  85.357873  76.851642
# 관악구   51.009421  90.091813  73.332066
# 광진구   52.524038  83.949881  69.730630
# 구로구   57.175269  82.713249  71.473054
# 금천구   55.355355  89.055065  75.673595
# 노원구   46.011396  82.339344  68.955383
# 도봉구   44.018583  82.820097  68.379991
# 동대문구  49.513889  89.517937  72.478683
# 동작구   44.146160  83.997548  65.187500
# 마포구   45.785570  84.436009  68.709328
# 서대문구  48.653668  79.643963  67.350967
# 서초구   47.501237  81.914404  66.333406
# 성동구   55.610236  90.188062  75.105843
# 성북구   58.704453  86.713287  75.847293
# 송파구   41.416221  85.233645  65.508318
# 양천구   47.330257  80.278129  64.863184
# 영등포구  43.555759  79.859311  64.615680
# 용산구   48.064806  82.065553  69.248905
# 은평구   55.142232  88.206522  74.660767
# 종로구   50.211327  82.992402  70.051580
# 중구    52.557856  84.010152  68.103196
# 중랑구   59.030544  85.262117  74.637681

# %%
del gu_df['강간(검거)']
del gu_df['강도(검거)']
del gu_df['살인(검거)']
del gu_df['절도(검거)']
del gu_df['폭력(검거)']
del gu_df['소계(발생)']
del gu_df['소계(검거)']

# %%
gu_df
# Out:
#       강간(발생)  강도(발생)      관서명  살인(발생)  절도(발생)  폭력(발생)       강간검거율       강도검거율  \
# 구별
# 강남구      708      14   강남서수서서       6    2951    3677   88.559322   78.571429
# 강동구      188      15      강동서       3    1640    1942   88.829787   93.333333
# 강북구      159       5      강북서       9     780    1817   83.018868   80.000000
# 강서구      265       6      강서서      10    1689    2445   83.773585   83.333333
# 관악구      403       3      관악서      12    2229    2614   87.096774  100.000000
# 광진구      255       4      광진서       2    1664    1676   87.843137  100.000000
# 구로구      197       5      구로서       6    1763    2204   72.081218  100.000000
# 금천구      117       7      금천서       4     999    1471   79.487179   85.714286
# 노원구      169       3      노원서       4    1404    2163   87.573964  100.000000
# 도봉구       82       2      도봉서       0     861    1234  106.097561  100.000000
# 동대문구     161       6     동대문서      10    1440    1784   88.198758   83.333333
# 동작구      226       1      동작서       1    1341    1631   53.539823  200.000000
# 마포구      348       4      마포서       9    1483    1844   82.471264   75.000000
# 서대문구     159       2     서대문서       3    1077    1292   93.710692   50.000000
# 서초구      396       6   서초서방배서       5    2021    2173   76.515152   66.666667
# 성동구      115       3      성동서       5    1016    1223   85.217391  100.000000
# 성북구      142       3   성북서종암서       4     988    1430   85.211268   66.666667
# 송파구      287      13      송파서       6    2429    2675   81.881533  130.769231
# 양천구      109       3      양천서       5    1517    1582   82.568807  100.000000
# 영등포구     315       6     영등포서       7    2188    2701   80.000000   83.333333
# 용산구      230       6      용산서       5    1111    1617   80.869565  100.000000
# 은평구      171       4   서부서은평서       4    1371    1840   84.795322   75.000000
# 종로구      192       7   종로서혜화서       9    1183    1711   76.041667  100.000000
# 중구       186       5  중부서남대문서       2    1642    1576   68.817204  120.000000
# 중랑구      183       5      중랑서      10    1506    2022   83.606557  120.000000
#
#            살인검거율      절도검거율      폭력검거율        검거율
# 구별
# 강남구    83.333333  50.525246  84.607017  71.302338
# 강동구   100.000000  47.621951  87.384140  70.274551
# 강북구    88.888889  62.820513  89.433132  81.552347
# 강서구    90.000000  63.351095  85.357873  76.851642
# 관악구   100.000000  51.009421  90.091813  73.332066
# 광진구   100.000000  52.524038  83.949881  69.730630
# 구로구   100.000000  57.175269  82.713249  71.473054
# 금천구   100.000000  55.355355  89.055065  75.673595
# 노원구    75.000000  46.011396  82.339344  68.955383
# 도봉구          NaN  44.018583  82.820097  68.379991
# 동대문구   80.000000  49.513889  89.517937  72.478683
# 동작구   100.000000  44.146160  83.997548  65.187500
# 마포구    88.888889  45.785570  84.436009  68.709328
# 서대문구  100.000000  48.653668  79.643963  67.350967
# 서초구   100.000000  47.501237  81.914404  66.333406
# 성동구   100.000000  55.610236  90.188062  75.105843
# 성북구   100.000000  58.704453  86.713287  75.847293
# 송파구   100.000000  41.416221  85.233645  65.508318
# 양천구   100.000000  47.330257  80.278129  64.863184
# 영등포구   57.142857  43.555759  79.859311  64.615680
# 용산구    60.000000  48.064806  82.065553  69.248905
# 은평구   100.000000  55.142232  88.206522  74.660767
# 종로구    66.666667  50.211327  82.992402  70.051580
# 중구    100.000000  52.557856  84.010152  68.103196
# 중랑구    90.000000  59.030544  85.262117  74.637681

# %%
columns = ['절도검거율','강간검거율', '강도검거율', '살인검거율', '폭력검거율']
gu_df_rate = gu_df[columns]

for row_index, row in gu_df_rate.iterrows():
    for column in columns:
        if row[column] > 100:
            gu_df.at[row_index, column] = 100

# %%
# gu_df[gu_df[['강간검거율','강도검거율','폭력검거율','절도검거율','살인검거율']]>100] = 100 => 마스킹 기법
gu_df['살인검거율'] = gu_df['살인검거율'].fillna(100) # 결측치(N/A)의 값 처리

# %%
popul_df = pd.read_csv('pop_kor.csv',encoding='utf-8')
popul_df.set_index('구별',inplace=True)

# %%
popul_df
# Out:
#          인구수
# 구별
# 강남구   537800
# 강동구   466472
# 강북구   302563
# 강서구   579768
# 관악구   499449
# 광진구   352627
# 구로구   421163
# 금천구   244891
# 노원구   514946
# 도봉구   319373
# 동대문구  352006
# 동작구   394364
# 마포구   378686
# 서대문구  315659
# 서초구   416167
# 성동구   292672
# 성북구   440142
# 송파구   663965
# 양천구   450487
# 영등포구  400908
# 용산구   237285
# 은평구   477173
# 종로구   153789
# 중구    131787
# 중랑구   391885

# %%
new_gu_df=gu_df.join(popul_df)

# %%
gu_df.sort_values(by='검거율', ascending=False, inplace=True)
gu_df.rename(columns = {'강간(발생)':'강간',
                        '강도(발생)':'강도',
                        '살인(발생)':'살인',
                        '절도(발생)':'절도',
                        '폭력(발생)':'폭력'}, inplace=True)

# %%
rc('font', family="AppleGothic")
sns.heatmap(gu_df[['강간', '강도', '살인', '절도', '폭력']])
# Out:
# <Axes: ylabel='구별'>

# %%
weight_col = gu_df[['강간', '강도', '살인', '절도', '폭력']].max()
crime_count_norm = gu_df[['강간', '강도', '살인', '절도', '폭력']] / weight_col
crime_count_norm
# Out:
#             강간        강도        살인        절도        폭력
# 구별
# 강북구   0.224576  0.333333  0.750000  0.264317  0.494153
# 강서구   0.374294  0.400000  0.833333  0.572348  0.664944
# 성북구   0.200565  0.200000  0.333333  0.334802  0.388904
# 금천구   0.165254  0.466667  0.333333  0.338529  0.400054
# 성동구   0.162429  0.200000  0.416667  0.344290  0.332608
# 은평구   0.241525  0.266667  0.333333  0.464588  0.500408
# 중랑구   0.258475  0.333333  0.833333  0.510335  0.549905
# 관악구   0.569209  0.200000  1.000000  0.755337  0.710906
# 동대문구  0.227401  0.400000  0.833333  0.487970  0.485178
# 구로구   0.278249  0.333333  0.500000  0.597425  0.599402
# 강남구   1.000000  0.933333  0.500000  1.000000  1.000000
# 강동구   0.265537  1.000000  0.250000  0.555744  0.528148
# 종로구   0.271186  0.466667  0.750000  0.400881  0.465325
# 광진구   0.360169  0.266667  0.166667  0.563877  0.455806
# 용산구   0.324859  0.400000  0.416667  0.376483  0.439761
# 노원구   0.238701  0.200000  0.333333  0.475771  0.588251
# 마포구   0.491525  0.266667  0.750000  0.502542  0.501496
# 도봉구   0.115819  0.133333  0.000000  0.291766  0.335600
# 중구    0.262712  0.333333  0.166667  0.556422  0.428610
# 서대문구  0.224576  0.133333  0.250000  0.364961  0.351373
# 서초구   0.559322  0.400000  0.416667  0.684853  0.590971
# 송파구   0.405367  0.866667  0.500000  0.823111  0.727495
# 동작구   0.319209  0.066667  0.083333  0.454422  0.443568
# 양천구   0.153955  0.200000  0.416667  0.514063  0.430242
# 영등포구  0.444915  0.400000  0.583333  0.741444  0.734566

# %%
sns.heatmap(crime_count_norm[['강간', '강도', '살인', '절도', '폭력']])
# Out:
# <Axes: ylabel='구별'>

# %%
plt.figure(figsize = (100, 100))

# %%
sns.heatmap(crime_count_norm.sort_values(by='살인', ascending=False), annot=True, fmt='f', linewidths=.7, cmap='Reds')

plt.title('범죄 발생(살인발생으로 정렬) - 각 항목별 최대값으로 나눠 정규화')
plt.show()

# %%
crime_ratio = crime_count_norm.div(new_gu_df['인구수'], axis=0) * 100000

# %%
sns.heatmap(crime_ratio.sort_values(by='살인', ascending=False), annot=True, fmt='f', linewidths=.7, cmap='Reds')
# Out:
# <Axes: ylabel='구별'>

# %%
crime_ratio['전체발생비율'] = crime_ratio.mean(axis=1)
# Out:
#            강간        강도        살인        절도        폭력    전체발생비율
# 구별
# 강남구  0.185943  0.173547  0.092971  0.185943  0.185943  0.164869
# 강동구  0.056924  0.214375  0.053594  0.119138  0.113222  0.111451
# 강북구  0.074225  0.110170  0.247882  0.087359  0.163322  0.136592
# 강서구  0.064559  0.068993  0.143736  0.098720  0.114691  0.098140
# 관악구  0.113967  0.040044  0.200221  0.151234  0.142338  0.129561

# %%
sns.heatmap(crime_ratio.sort_values(by='전체발생비율', ascending=False), annot=True, fmt='f', linewidths=.5, cmap='Reds')
plt.title('범죄 발생(전체발생비율로 정렬) - 각 항목을 정규화한 후 인구로 나눔')
plt.figure(figsize=(200,200))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import json
from pyprnt import prnt

geo_path = 'skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
prnt(geo_str, width= 80)
# Out:
# ┌────────┬─────────────────────────────────────────────────────────────────────┐
# │type    │FeatureCollection                                                    │
# │features│┌──┬────────────────────────────────────────────────────────────────┐│
# │        ││0 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │강동구                                                │││
# │        ││  ││properties│┌─────────┬───────────┐                            │││
# │        ││  ││          ││code     │11250      │                            │││
# │        ││  ││          ││name     │강동구        │                            │││
# │        ││  ││          ││name_eng │Gangdong-gu│                            │││
# │        ││  ││          ││base_year│2013       │                            │││
# │        ││  ││          │└─────────┴───────────┘                            │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬──────────────────────────┐       ││││
# │        ││  ││          ││           ││0│┌─┬──────────────────────┐│       ││││
# │        ││  ││          ││           ││ ││0│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.11519584981606│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.557533180704915│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││1│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.16683184366129│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.57672487388627 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││2│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.18408792330152│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.55814280369575 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││3│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.16530984307447│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.54221851258693 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││4│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.14672806823502│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.51415680680291 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││5│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.12123165719615│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.52528270089    │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││6│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.1116764203608 │││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.540669955324965│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││7│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.11519584981606│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.557533180704915│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ │└─┴──────────────────────┘│       ││││
# │        ││  ││          ││           │└─┴──────────────────────────┘       ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││1 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │송파구                                                │││
# │        ││  ││properties│┌─────────┬─────────┐                              │││
# │        ││  ││          ││code     │11240    │                              │││
# │        ││  ││          ││name     │송파구      │                              │││
# │        ││  ││          ││name_eng │Songpa-gu│                              │││
# │        ││  ││          ││base_year│2013     │                              │││
# │        ││  ││          │└─────────┴─────────┘                              │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬───────────────────────────┐      ││││
# │        ││  ││          ││           ││0│┌──┬──────────────────────┐│      ││││
# │        ││  ││          ││           ││ ││0 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.0690698130372 │││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.522279423505026│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││1 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.10087519791962│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.524841220167055│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││2 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.1116764203608 │││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.540669955324965│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││3 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.12123165719615│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.52528270089    │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││4 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.14672806823502│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.51415680680291 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││5 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.1634944215765 │││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.497445406097484│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││6 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.14206058413274│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.47089819098501 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││7 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.12440571080893│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.46240445587048 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││8 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.11117085201238│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.485708381512445│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││9 │┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.0719146000724│ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.50224013587669│ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ ││10│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.0690698130372 │││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.522279423505026│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ │└──┴──────────────────────┘│      ││││
# │        ││  ││          ││           │└─┴───────────────────────────┘      ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││2 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │강남구                                                │││
# │        ││  ││properties│┌─────────┬──────────┐                             │││
# │        ││  ││          ││code     │11230     │                             │││
# │        ││  ││          ││name     │강남구       │                             │││
# │        ││  ││          ││name_eng │Gangnam-gu│                             │││
# │        ││  ││          ││base_year│2013      │                             │││
# │        ││  ││          │└─────────┴──────────┘                             │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬───────────────────────────┐      ││││
# │        ││  ││          ││           ││0│┌──┬──────────────────────┐│      ││││
# │        ││  ││          ││           ││ ││0 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.05867359288398│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.52629974922568 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││1 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.0690698130372 │││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.522279423505026│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││2 │┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.0719146000724│ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.50224013587669│ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ ││3 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.11117085201238│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.485708381512445│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││4 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.12440571080893│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.46240445587048 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││5 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.09842759318751│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.45862253857461 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││6 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.08640440578156│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.472697935184655│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││7 │┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.0559170481904│ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.4659228914077 │ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ ││8 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.03621915098798│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.48175802427603 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││9 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.01397119667513│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.52503988289669 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││10│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.02302831890559│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.53231899582663 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││11│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.05867359288398│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.52629974922568 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ │└──┴──────────────────────┘│      ││││
# │        ││  ││          ││           │└─┴───────────────────────────┘      ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││3 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │서초구                                                │││
# │        ││  ││properties│┌─────────┬─────────┐                              │││
# │        ││  ││          ││code     │11220    │                              │││
# │        ││  ││          ││name     │서초구      │                              │││
# │        ││  ││          ││name_eng │Seocho-gu│                              │││
# │        ││  ││          ││base_year│2013     │                              │││
# │        ││  ││          │└─────────┴─────────┘                              │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬───────────────────────────┐      ││││
# │        ││  ││          ││           ││0│┌──┬──────────────────────┐│      ││││
# │        ││  ││          ││           ││ ││0 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.01397119667513│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.52503988289669 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││1 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.03621915098798│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.48175802427603 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││2 │┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.0559170481904│ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.4659228914077 │ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ ││3 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.08640440578156│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.472697935184655│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││4 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.09842759318751│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.45862253857461 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││5 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.09046928565951│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.44296826114185 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││6 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.06778107605433│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.426197424057314│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││7 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.04957232987142│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.42805836845694 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││8 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.03881782597922│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.45382039851715 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││9 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.99072073195462│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.455326143310025│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││10│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.98367668291802│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.473856492692086│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││11│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.98223807916081│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.509314966770326│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││12│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.01397119667513│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.52503988289669 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ │└──┴──────────────────────┘│      ││││
# │        ││  ││          ││           │└─┴───────────────────────────┘      ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││4 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │관악구                                                │││
# │        ││  ││properties│┌─────────┬─────────┐                              │││
# │        ││  ││          ││code     │11210    │                              │││
# │        ││  ││          ││name     │관악구      │                              │││
# │        ││  ││          ││name_eng │Gwanak-gu│                              │││
# │        ││  ││          ││base_year│2013     │                              │││
# │        ││  ││          │└─────────┴─────────┘                              │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬───────────────────────────┐      ││││
# │        ││  ││          ││           ││0│┌──┬──────────────────────┐│      ││││
# │        ││  ││          ││           ││ ││0 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.98367668291802│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.473856492692086│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││1 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.99072073195462│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.455326143310025│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││2 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.96520439085143│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.438249784006246│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││3 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.95000001010182│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.43613451165719 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││4 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.93084408056525│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.447382928333994│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││5 │┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.9167728146601│ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.45490566423789│ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ ││6 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.90156094129895│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.47753842789901 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││7 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.90531975801812│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.48218087575429 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││8 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.94922661389508│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.49125437495649 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││9 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.9725891850662 │││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.472561363278125│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││10│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.98367668291802│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.473856492692086│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ │└──┴──────────────────────┘│      ││││
# │        ││  ││          ││           │└─┴───────────────────────────┘      ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││5 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │동작구                                                │││
# │        ││  ││properties│┌─────────┬──────────┐                             │││
# │        ││  ││          ││code     │11200     │                             │││
# │        ││  ││          ││name     │동작구       │                             │││
# │        ││  ││          ││name_eng │Dongjak-gu│                             │││
# │        ││  ││          ││base_year│2013      │                             │││
# │        ││  ││          │└─────────┴──────────┘                             │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬──────────────────────────┐       ││││
# │        ││  ││          ││           ││0│┌─┬──────────────────────┐│       ││││
# │        ││  ││          ││           ││ ││0│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.98223807916081│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.509314966770326│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││1│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.98367668291802│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.473856492692086│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││2│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.9725891850662 │││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.472561363278125│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││3│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.94922661389508│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.49125437495649 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││4│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.90531975801812│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.48218087575429 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││5│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.92177893174825│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.494889877415176│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││6│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.92810628828279│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.51329595732015 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││7│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.95249990298159│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.51722500741813 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││8│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.98223807916081│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.509314966770326│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ │└─┴──────────────────────┘│       ││││
# │        ││  ││          ││           │└─┴──────────────────────────┘       ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││6 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │영등포구                                               │││
# │        ││  ││properties│┌─────────┬───────────────┐                        │││
# │        ││  ││          ││code     │11190          │                        │││
# │        ││  ││          ││name     │영등포구           │                        │││
# │        ││  ││          ││name_eng │Yeongdeungpo-gu│                        │││
# │        ││  ││          ││base_year│2013           │                        │││
# │        ││  ││          │└─────────┴───────────────┘                        │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬──────────────────────────┐       ││││
# │        ││  ││          ││           ││0│┌─┬──────────────────────┐│       ││││
# │        ││  ││          ││           ││ ││0│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.89184663862764│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.547373974997114│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││1│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.94566733083212│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.526617542453366│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││2│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.95249990298159│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.51722500741813 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││3│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.92810628828279│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.51329595732015 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││4│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.92177893174825│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.494889877415176│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││5│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.90531975801812│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.48218087575429 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││6│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.89594776782485│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.504675281309176│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││7│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.88156402353862│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.513970034765684│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││8│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.88825757860099│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.54079733630232 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││9│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.89184663862764│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.547373974997114│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ │└─┴──────────────────────┘│       ││││
# │        ││  ││          ││           │└─┴──────────────────────────┘       ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││7 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │금천구                                                │││
# │        ││  ││properties│┌─────────┬────────────┐                           │││
# │        ││  ││          ││code     │11180       │                           │││
# │        ││  ││          ││name     │금천구         │                           │││
# │        ││  ││          ││name_eng │Geumcheon-gu│                           │││
# │        ││  ││          ││base_year│2013        │                           │││
# │        ││  ││          │└─────────┴────────────┘                           │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬──────────────────────────┐       ││││
# │        ││  ││          ││           ││0│┌─┬──────────────────────┐│       ││││
# │        ││  ││          ││           ││ ││0│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.90156094129895│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.47753842789901 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││1│┌─┬─────────────────┐ ││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.9167728146601│ ││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.45490566423789│ ││       ││││
# │        ││  ││          ││           ││ ││ │└─┴─────────────────┘ ││       ││││
# │        ││  ││          ││           ││ ││2│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.93084408056525│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.447382928333994│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││3│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.9025831711697 │││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.434549366349124│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││4│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.87683271502428│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.482576591607305│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││5│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.90156094129895│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.47753842789901 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ │└─┴──────────────────────┘│       ││││
# │        ││  ││          ││           │└─┴──────────────────────────┘       ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││8 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │구로구                                                │││
# │        ││  ││properties│┌─────────┬───────┐                                │││
# │        ││  ││          ││code     │11170  │                                │││
# │        ││  ││          ││name     │구로구    │                                │││
# │        ││  ││          ││name_eng │Guro-gu│                                │││
# │        ││  ││          ││base_year│2013   │                                │││
# │        ││  ││          │└─────────┴───────┘                                │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬───────────────────────────┐      ││││
# │        ││  ││          ││           ││0│┌──┬──────────────────────┐│      ││││
# │        ││  ││          ││           ││ ││0 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.82688081517314│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.50548972232896 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││1 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.88156402353862│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.513970034765684│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││2 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.89594776782485│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.504675281309176│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││3 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.90531975801812│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.48218087575429 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││4 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.90156094129895│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.47753842789901 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││5 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.87683271502428│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.482576591607305│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││6 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.84762676054953│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.47146723936323 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││7 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.83549485076196│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.474098236975095│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││8 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.82264796791348│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.4878476492147  │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││9 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.82504736331406│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.50302612640443 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││10│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.82688081517314│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.50548972232896 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ │└──┴──────────────────────┘│      ││││
# │        ││  ││          ││           │└─┴───────────────────────────┘      ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││9 │┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │강서구                                                │││
# │        ││  ││properties│┌─────────┬──────────┐                             │││
# │        ││  ││          ││code     │11160     │                             │││
# │        ││  ││          ││name     │강서구       │                             │││
# │        ││  ││          ││name_eng │Gangseo-gu│                             │││
# │        ││  ││          ││base_year│2013      │                             │││
# │        ││  ││          │└─────────┴──────────┘                             │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬───────────────────────────┐      ││││
# │        ││  ││          ││           ││0│┌──┬──────────────────────┐│      ││││
# │        ││  ││          ││           ││ ││0 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.79575768552907│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.57881087633202 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││1 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.80702115023597│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.60123001013228 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││2 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.82251438477105│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.5880430810082  │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││3 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.85984199399667│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.571847855292745│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││4 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.89184663862764│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.547373974997114│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││5 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.88825757860099│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.54079733630232 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││6 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.86637464321238│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.54859191094823 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││7 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.86610073476395│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.52699964144669 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││8 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.84257291943153│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.52373707805596 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││9 │┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.8242331426722│ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.53788078753248│ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ ││10│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.77324417717703│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.5459123450554  │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││11│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.76979180579352│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.55139183008809 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││12│┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.79575768552907│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.57881087633202 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ │└──┴──────────────────────┘│      ││││
# │        ││  ││          ││           │└─┴───────────────────────────┘      ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││10│┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │양천구                                                │││
# ...
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬──────────────────────────┐       ││││
# │        ││  ││          ││           ││0│┌─┬──────────────────────┐│       ││││
# │        ││  ││          ││           ││ ││0│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.02547266349976│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.568943552237734│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││1│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.05005601081567│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.567577612590846│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││2│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.07421053024362│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.55724769712085 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││3│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.05867359288398│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.52629974922568 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││4│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.02302831890559│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.53231899582663 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││5│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.01070894177482│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.54118048964762 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││6│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.02547266349976│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.568943552237734│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ │└─┴──────────────────────┘│       ││││
# │        ││  ││          ││           │└─┴──────────────────────────┘       ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││22│┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │용산구                                                │││
# │        ││  ││properties│┌─────────┬──────────┐                             │││
# │        ││  ││          ││code     │11030     │                             │││
# │        ││  ││          ││name     │용산구       │                             │││
# │        ││  ││          ││name_eng │Yongsan-gu│                             │││
# │        ││  ││          ││base_year│2013      │                             │││
# │        ││  ││          │└─────────┴──────────┘                             │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬──────────────────────────┐       ││││
# │        ││  ││          ││           ││0│┌─┬──────────────────────┐│       ││││
# │        ││  ││          ││           ││ ││0│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.01070894177482│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.54118048964762 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││1│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.02302831890559│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.53231899582663 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││2│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.01397119667513│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.52503988289669 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││3│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.98223807916081│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.509314966770326│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││4│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.95249990298159│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.51722500741813 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││5│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.94566733083212│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.526617542453366│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││6│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.96448570553055│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.548705692021635│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││7│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.98752996903328│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.55094818807139 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││8│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.01070894177482│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.54118048964762 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ │└─┴──────────────────────┘│       ││││
# │        ││  ││          ││           │└─┴──────────────────────────┘       ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││23│┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │중구                                                 │││
# │        ││  ││properties│┌─────────┬───────┐                                │││
# │        ││  ││          ││code     │11020  │                                │││
# │        ││  ││          ││name     │중구     │                                │││
# │        ││  ││          ││name_eng │Jung-gu│                                │││
# │        ││  ││          ││base_year│2013   │                                │││
# │        ││  ││          │└─────────┴───────┘                                │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬──────────────────────────┐       ││││
# │        ││  ││          ││           ││0│┌─┬──────────────────────┐│       ││││
# │        ││  ││          ││           ││ ││0│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.02547266349976│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.568943552237734│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││1│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.01070894177482│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.54118048964762 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││2│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.98752996903328│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.55094818807139 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││3│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.96448570553055│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.548705692021635│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││4│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.96358226710812│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.55605635475154 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││5│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│126.96873633279075│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.56313604690827 │││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ ││6│┌─┬──────────────────┐││       ││││
# │        ││  ││          ││           ││ ││ ││0│127.02547266349976│││       ││││
# │        ││  ││          ││           ││ ││ ││1│37.568943552237734│││       ││││
# │        ││  ││          ││           ││ ││ │└─┴──────────────────┘││       ││││
# │        ││  ││          ││           ││ │└─┴──────────────────────┘│       ││││
# │        ││  ││          ││           │└─┴──────────────────────────┘       ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        ││24│┌──────────┬───────────────────────────────────────────────────┐││
# │        ││  ││type      │Feature                                            │││
# │        ││  ││id        │종로구                                                │││
# │        ││  ││properties│┌─────────┬─────────┐                              │││
# │        ││  ││          ││code     │11010    │                              │││
# │        ││  ││          ││name     │종로구      │                              │││
# │        ││  ││          ││name_eng │Jongno-gu│                              │││
# │        ││  ││          ││base_year│2013     │                              │││
# │        ││  ││          │└─────────┴─────────┘                              │││
# │        ││  ││geometry  │┌───────────┬─────────────────────────────────────┐│││
# │        ││  ││          ││type       │Polygon                              ││││
# │        ││  ││          ││coordinates│┌─┬───────────────────────────┐      ││││
# │        ││  ││          ││           ││0│┌──┬──────────────────────┐│      ││││
# │        ││  ││          ││           ││ ││0 │┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.9738864128702│ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.62949634786888│ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ ││1 │┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.977175406416 │ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.62859715400388│ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ ││2 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.98879865992384│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.6118927319756  │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││3 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.99348293358314│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.588565457216156│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││4 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.02527254528003│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.57524616245249 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││5 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│127.02547266349976│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.568943552237734│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││6 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.96873633279075│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.56313604690827 │││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││7 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.95565425846463│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.576080790881456│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││8 │┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.9524752030572│ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.60508692737045│ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ ││9 │┌─┬──────────────────┐││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.95427017006129│││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.622033431339425│││      ││││
# │        ││  ││          ││           ││ ││  │└─┴──────────────────┘││      ││││
# │        ││  ││          ││           ││ ││10│┌─┬─────────────────┐ ││      ││││
# │        ││  ││          ││           ││ ││  ││0│126.9738864128702│ ││      ││││
# │        ││  ││          ││           ││ ││  ││1│37.62949634786888│ ││      ││││
# │        ││  ││          ││           ││ ││  │└─┴─────────────────┘ ││      ││││
# │        ││  ││          ││           ││ │└──┴──────────────────────┘│      ││││
# │        ││  ││          ││           │└─┴───────────────────────────┘      ││││
# │        ││  ││          │└───────────┴─────────────────────────────────────┘│││
# │        ││  │└──────────┴───────────────────────────────────────────────────┘││
# │        │└──┴────────────────────────────────────────────────────────────────┘│
# └────────┴─────────────────────────────────────────────────────────────────────┘

# %%
import folium

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data=geo_str,
               data=crime_ratio['전체발생비율'], # 시각화 대상 데이터
               columns=[crime_ratio.index, crime_ratio['전체발생비율']],
               fill_color='PuRd',
               key_on= 'feature.id')

# %%
staion_name = []
for name in df['관서명']:
    staion_name.append('서울' + str(name[:-1]) + '경찰서')

# %%
df['경찰서'] = staion_name
df['검거율'] = df['소계(검거)']/df['소계(발생)'] * 100

# %%
def reRange(x, oldMin, oldMax, newMin, newMax):
    return (x - oldMin)*(newMax - newMin) / (oldMax - oldMin) + newMin 

df['점수'] = reRange(df['검거율'], min(df['검거율']), max(df['검거율']), 1, 100)
# Out:
#      관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 1    중부서    2057    1406       1       1       3       4     113      76
# 2    종로서    1694    1179       9       6       4       4     115      93
# 3   남대문서    1354     917       1       1       2       2      73      52
# 4   서대문서    2533    1706       3       3       2       1     159     149
# 5    혜화서    1408     994       0       0       3       3      77      53
# 6    용산서    2969    2056       5       3       6       6     230     186
# 7    성북서    1208     922       0       0       2       2      95      77
# 8   동대문서    3401    2465      10       8       6       5     161     142
# 9    마포서    3688    2534       9       8       4       3     348     287
# 10  영등포서    5217    3371       7       4       6       5     315     252
# 11   성동서    2362    1774       5       5       3       3     115      98
# 12   동작서    3200    2086       1       1       1       2     226     121
# 13   광진서    3601    2511       2       2       4       4     255     224
# 14   서부서    1362    1065       3       3       3       2      76      71
# 15   강북서    2770    2259       9       8       5       4     159     132
# 16   금천서    2598    1966       4       4       7       6     117      93
# 17   중랑서    3726    2781      10       9       5       6     183     153
# 18   강남서    4754    3373       5       3      12      10     513     433
# 19   관악서    5261    3858      12      12       3       3     403     351
# 20   강서서    4415    3393      10       9       6       5     265     222
# 21   강동서    3788    2662       3       3      15      14     188     167
# 22   종암서    1359    1025       4       4       1       0      47      44
# 23   구로서    4175    2984       6       6       5       5     197     142
# 24   서초서    3765    2476       4       4       5       3     333     253
# 25   양천서    3216    2086       5       5       3       3     109      90
# 26   송파서    5410    3544       6       6      13      17     287     235
# 27   노원서    3743    2581       4       3       3       3     169     148
# 28   방배서     836     576       1       1       1       1      63      50
# 29   은평서    2028    1466       1       1       1       1      95      74
# 30   도봉서    2179    1490       0       0       2       2      82      87
# 31   수서서    2602    1872       1       2       2       1     195     194
#
#     절도(발생)  절도(검거)  폭력(발생)  폭력(검거)    구별       경찰서        검거율          점수
# 1      943     495     997     830    중구   서울중부경찰서  68.351969   22.839754
# 2      602     284     964     792   종로구   서울종로경찰서  69.598583   30.126597
# 3      699     368     579     494    중구  서울남대문경찰서  67.725258   19.176440
# 4     1077     524    1292    1029  서대문구  서울서대문경찰서  67.350967   16.988593
# 5      581     310     747     628   종로구   서울혜화경찰서  70.596591   35.960257
# 6     1111     534    1617    1327   용산구   서울용산경찰서  69.248905   28.082622
# 7      439     233     672     610   성북구   서울성북경찰서  76.324503   69.441657
# 8     1440     713    1784    1597  동대문구  서울동대문경찰서  72.478683   46.961659
# 9     1483     679    1844    1557   마포구   서울마포경찰서  68.709328   24.928625
# 10    2188     953    2701    2157  영등포구  서울영등포경찰서  64.615680    1.000000
# 11    1016     565    1223    1103   성동구   서울성동경찰서  75.105843   62.318212
# 12    1341     592    1631    1370   동작구   서울동작경찰서  65.187500    4.342466
# 13    1664     874    1676    1407   광진구   서울광진경찰서  69.730630   30.898453
# 14     532     322     748     667   은평구   서울서부경찰서  78.193833   80.368458
# 15     780     490    1817    1625   강북구   서울강북경찰서  81.552347  100.000000
# 16     999     553    1471    1310   금천구   서울금천경찰서  75.673595   65.636899
# 17    1506     889    2022    1724   중랑구   서울중랑경찰서  74.637681   59.581665
# 18    1941    1016    2283    1911   강남구   서울강남경찰서  70.950778   38.030590
# 19    2229    1137    2614    2355   관악구   서울관악경찰서  73.332066   51.949946
# 20    1689    1070    2445    2087   강서구   서울강서경찰서  76.851642   72.522945
# 21    1640     781    1942    1697   강동구   서울강동경찰서  70.274551   34.077836
# 22     549     347     758     630   성북구   서울종암경찰서  75.423105   64.172709
# 23    1763    1008    2204    1823   구로구   서울구로경찰서  71.473054   41.083451
# 24    1673     801    1750    1415   서초구   서울서초경찰서  65.763612    7.710018
# 25    1517     718    1582    1270   양천구   서울양천경찰서  64.863184    2.446740
# 26    2429    1006    2675    2280   송파구   서울송파경찰서  65.508318    6.217745
# 27    1404     646    2163    1781   노원구   서울노원경찰서  68.955383   26.366897
# 28     348     159     423     365   서초구   서울방배경찰서  68.899522   26.040367
# 29     839     434    1092     956   은평구   서울은평경찰서  72.287968   45.846876
# 30     861     379    1234    1022   도봉구   서울도봉경찰서  68.379991   23.003551
# 31    1010     475    1394    1200   강남구   서울수서경찰서  71.944658   43.840121

# %%
import googlemaps

gmaps = googlemaps.Client(key="AIzaSyBWmcGTO2FX23g25LO9Hg0D_ESh4LGwPJo")

lat = []
lng = []

for name in df['경찰서']:
    # gmaps.reverse_geocode((longitude 값, latitude 값), language="ko") == 경도 & 위도 값으로 주소값 가져오기
    # gmaps.geocode('한글 주소', language="ko") 로 위도/경도, 우편번호까지 알 수 있음
    tmpMap = gmaps.geocode(name) # ex) 서울강남경찰서
    tmpLoc = tmpMap[0].get('geometry') # 배열 형태( [~] )로 들어오기 때문에 [0]으로 호출
    lat.append(tmpLoc['location']['lat']) # dict(tmpLoc)의 데이터는 dict['key값'] 로 value 호출
    lng.append(tmpLoc['location']['lng'])
    
df['lat'] = lat
df['lng'] = lng

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

for n in df.index: # range(len(df.index)) 처럼 할 필요 없이 바로 df.index 를 순회하여 record 자체에 접근할 수 있음
    # 경찰서별로 원형 마커를 생성하여 점수를 radius 로 매겨 지도에 표시함
    # folium.Circle() 의 경우는 radius가 자동으로 meter 단위가 됩니다. (아래 CircleMarker에서의 radius는 pixel 단위)
    folium.CircleMarker ([df['lat'][n], df['lng'][n]], 
                         radius=df['점수'][n]*0.5, # circle 의 크기를 결정
                         color='#3186cc', fill=True, fill_color='#3186cc').add_to(map)

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

map.choropleth(geo_data = geo_str,
               data = crime_ratio['전체발생비율'],
               columns = [crime_ratio.index, crime_ratio['전체발생비율']],
               fill_color = 'PuRd', #PuRd, YlGnBu
               key_on = 'feature.id')

for n in df.index:
    folium.CircleMarker([df['lat'][n], df['lng'][n]], 
                        radius=df['점수'][n]*0.7, # 0.5 -> 0.7
                        color='#3186cc', fill=True, fill_color='#3186cc').add_to(map)

# %%
geo_path = 'skorea-2018-municipalities-geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
in_seoul = [] # 서울 내 지역만 모을 리스트

for feature in geo_str['features']:
    if feature['properties']['code'].startswith('11'): # 서울 내 지역의 경우 code가 11로 시작 (11010~11250)
        in_seoul.append(feature)
        
del geo_str['features']
geo_str['features'] = in_seoul

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data = geo_str,               
               data = crime_ratio['전체발생비율'], 
               columns = [crime_ratio.index, crime_ratio['전체발생비율']],
               fill_color = 'PuRd',
               
               key_on = 'feature.properties.name')

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

map.choropleth(geo_data = geo_str,
               data = crime_ratio['전체발생비율'],
               columns = [crime_ratio.index, crime_ratio['전체발생비율']],
               fill_color = 'PuRd', 
               key_on = 'feature.properties.name')

for n in df.index:
    folium.CircleMarker([df['lat'][n], df['lng'][n]], 
                        radius=df['점수'][n]*0.7, 
                        color='#3186cc', fill=True, fill_color='#3186cc').add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_84259c7324135da60ec7945b8d44df6b {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84259c7324135da60ec7945b8d44df6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_84259c7324135da60ec7945b8d44df6b = L.map(
#                                   &#x27;map_84259c7324135da60ec7945b8d44df6b&#x27;,
#                                   {center: [37.5502,126.982],
#                                   zoom: 11,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_b2446738f690ff20070da5b6253d43d2 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_84259c7324135da60ec7945b8d44df6b);
#
#
#
#
#
#                 var geo_json_bbb534f08216518ddf754b30a2064474 = L.geoJson(
#                     {&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[126.97468086053324, 37.629805433945975], [126.97496550641705, 37.62902584732434], [126.97619200024447, 37.629086831818235], [126.97841861289852, 37.62929009924553], [126.97952791872238, 37.62889299772442], [126.97993254143336, 37.62855138674378], [126.97997245663913, 37.62845560448294], [126.98004544991201, 37.628280435760445], [126.97960294035302, 37.626371002121644], [126.98090237068868, 37.625391798020395], [126.98168803207568, 37.62449661776251], [126.98184774907679, 37.62431463061319], [126.98310978892584, 37.622104640078], [126.98365101056845, 37.62115092912986], [126.98355888565348, 37.620963267437894], [126.98317999257362, 37.62018285183479], [126.9831620682276, 37.6192347829173], [126.9837143460292, 37.61775856638039], [126.98453643307462, 37.61598061074333], [126.985901535693, 37.612194740823796], [126.9857804843237, 37.61090698776889], [126.98586523076781, 37.60946995153532], [126.98623831468637, 37.607736782107125], [126.98675598705915, 37.60608704965549], [126.98677074181907, 37.60458661863664], [126.9866691435352, 37.604023824468506], [126.98589778740545, 37.60363176153766], [126.98259603020061, 37.60224271097029], [126.9806843648502, 37.60161031225276], [126.97880665420949, 37.60101042316433], [126.97852169405631, 37.60099248777431], [126.97841693568347, 37.600914296754326], [126.97830701720335, 37.600830447643865], [126.97768193317589, 37.60024002437466], [126.9774909383084, 37.599649166074286], [126.97719804274786, 37.59864847380904], [126.97672044958631, 37.59790077442683], [126.97713557023776, 37.59768356016227], [126.97874017601505, 37.59663493476611], [126.97911091252222, 37.596394270916285], [126.98148823597326, 37.59533576215007], [126.98292059990969, 37.594775982193624], [126.98384405286397, 37.59443543461552], [126.98432317109803, 37.59437806733553], [126.98450416009975, 37.59437471448865], [126.9846156223434, 37.59438909275369], [126.98463785016311, 37.59439408049888], [126.98464216134765, 37.59439557572296], [126.98466445483236, 37.59440401859687], [126.98474441343951, 37.594434717703415], [126.98479058424006, 37.594451906863895], [126.98487868712496, 37.59446656147479], [126.98514831673403, 37.594501790677405], [126.98542946037894, 37.59444945443447], [126.98577892249222, 37.59425495254234], [126.98851705023388, 37.59194143989685], [126.98886704210804, 37.59164472228141], [126.98907495209343, 37.59142090222344], [126.98908433025534, 37.59140908294205], [126.98962720754243, 37.59139763837295], [126.99366158210871, 37.59149362412968], [126.99744340490047, 37.59221011675905], [126.99845395445548, 37.59247126210828], [127.00182654761254, 37.59117745103071], [127.00408062474574, 37.58773357887768], [127.00656012457411, 37.58553460128624], [127.00863797169242, 37.58045993171883], [127.01051131122689, 37.58025727035416], [127.0111260694579, 37.58104392936677], [127.0111791729006, 37.58109176738164], [127.01169858419944, 37.58150458110694], [127.0117885968101, 37.58157458058202], [127.0120845128743, 37.581585674737156], [127.01222457400928, 37.581550873062085], [127.0124187027769, 37.58150235525185], [127.01253278245557, 37.58147102693477], [127.01262598550882, 37.58144402349896], [127.01274334585422, 37.58141185855377], [127.01285982629548, 37.58138609392204], [127.01314825156626, 37.58143362114355], [127.01324571819538, 37.58145032393419], [127.0141191759168, 37.581820171723166], [127.01474563580459, 37.582305831258346], [127.01483334205895, 37.58233145649853], [127.01491713941482, 37.582244907556685], [127.01638580146992, 37.58193775580977], [127.01673363020068, 37.58169269831286], [127.01829142498933, 37.579049416348774], [127.01830026223921, 37.57903270179077], [127.0187770633223, 37.57751723332606], [127.02179265953254, 37.57888146291368], [127.02313849621643, 37.578 ...
